# %% [markdown]
# # titulo nivel 1!!!
#
# ## titulo nivel 2!!!
#
# ### titulo nivel 3!!!
#
# ---
#
# <br />
# *Italico*<br />
# **Negrito**<br />
# ***Negrito e Italico***<br />
#
# Este é um texto normal!
#
# ---
# <br />
# # Exemplo de código *Hello word* no *markdown*:<br />
# `print("Hello Word")`.
# <br />
# <br />
# 1. Você vai clicar em **Não**?<br /><br />
# <input type="radio" name="questao"><span>sim</span><br />
# <input type="radio" name="questao"><span>não</span><br />
# <br />
# 2. Informe suas habilidades:<br />
# <br />
# <input type="checkbox" name="hab" /> Operador de Micro<br />
# <input type="checkbox" name="hab" /> HTML<br />
# <input type="checkbox" name="hab" /> Java<br />
# <input type="checkbox" name="hab" /> Python<br />
# <input type="checkbox" name="hab" /> javascript<br />
# <br />
#
# ---
#
# # Tópicos:
#
#
# - Tópico 1
# - Tópico 2
# - Tópico 3
#
# ## Numeração:
#
# 1. Numeração 1
# 1. Numeração 2
# 1. Numeração 3

# %% [markdown]
# # Trabalhando com códigos em jupyter:
#
# ---
#
# abaixo segue um exemplo de um codigo funcional em ***Python*** rodando em um notebook:

# %%
n1 = 15
n2 = 5
n3 = n1+n2

print(f' Qual o nome do filme?\nResposta =  código da')
# Out:
#  Qual o nome do filme?
# Resposta =  código da

# %% [markdown]
# **Repare que o código-fonte das células consideram o resultado das células anteriores do
# mesmo notebook. Observe no código a seguir:**

# %%
x = 10

print (f'Resultado = {x*n3}')
# Out:
# Resultado = 200

# %% [markdown]
# **Vamos ver como um código de entrada de dados se comporta em um notebook:**

# %%
texto = input('Informe um texto a ser exibido na célular')

print(texto)
# Out:
# Itallo

# %% [markdown]
# ---

# %% [markdown]
# # Adicionando imagem em Markdown
#
# <br />
#
# **Imagem no markdown**
# <br />
#
# ![image.png](attachment:image.png)
